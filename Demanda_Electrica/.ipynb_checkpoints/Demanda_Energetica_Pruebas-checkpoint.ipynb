# %%
token = 'cb25867a53d723d058c6d15d29d416fc981bfe92d68e1709ae61ae0157806312'
token
# Out:
# 'cb25867a53d723d058c6d15d29d416fc981bfe92d68e1709ae61ae0157806312'

# %%
# url para llamar a la API de E-SIOS
url = 'https://api.esios.ree.es/indicators'

# %%
# paquetes para importar
import requests
import json
import numpy as np
import datetime
import string
import pandas as pd
import matplotlib.pyplot as plt

# %%
start_date='01-01-2014T00:00:00 00:00'
end_date='31-12-2021T23:00:00 00:00'
date_type='datos'

url_resumen = 'https://api.esios.ree.es/indicators/1293/?start_date='+start_date+'&end_date='+end_date+'&time_trunc=hour'
demanda_historico = requests.get(
    url_resumen, 
    headers = {
        'Accept': 'application/json; application/vnd.esios-api-v1+json',
        'Host' : 'api.esios.ree.es',
        'Content-Type':'application/json',
        'Authorization':'Token token="%s"' % (token),
        'Cookie': ''
    }
)

demanda_historico.json()
# Out:
# {'indicator': {'name': 'Demanda real',
#   'short_name': 'Demanda real',
#   'id': 1293,
#   'composited': False,
#   'step_type': 'linear',
#   'disaggregated': False,
#   'magnitud': [{'name': 'Potencia', 'id': 20}],
#   'tiempo': [{'name': 'Diez minutos', 'id': 225}],
#   'geos': [{'geo_id': 8741, 'geo_name': 'Península'}],
#   'values_updated_at': '2021-12-31T23:09:00.000+01:00',
#   'values': [{'value': 145810.0,
#     'datetime': '2014-01-01T00:00:00.000+01:00',
#     'datetime_utc': '2013-12-31T23:00:00Z',
#     'tz_time': '2013-12-31T23:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 140192.0,
#     'datetime': '2014-01-01T01:00:00.000+01:00',
#     'datetime_utc': '2014-01-01T00:00:00Z',
#     'tz_time': '2014-01-01T00:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 130035.0,
#     'datetime': '2014-01-01T02:00:00.000+01:00',
#     'datetime_utc': '2014-01-01T01:00:00Z',
# ...

# %%
# vamos a convertir en dataframe
demanda_values = demanda_historico.json()['indicator']['values']
demanda_values
# Out:
# [{'value': 145810.0,
#   'datetime': '2014-01-01T00:00:00.000+01:00',
#   'datetime_utc': '2013-12-31T23:00:00Z',
#   'tz_time': '2013-12-31T23:00:00.000Z',
#   'geo_id': 8741,
#   'geo_name': 'Península'},
#  {'value': 140192.0,
#   'datetime': '2014-01-01T01:00:00.000+01:00',
#   'datetime_utc': '2014-01-01T00:00:00Z',
#   'tz_time': '2014-01-01T00:00:00.000Z',
#   'geo_id': 8741,
#   'geo_name': 'Península'},
#  {'value': 130035.0,
#   'datetime': '2014-01-01T02:00:00.000+01:00',
#   'datetime_utc': '2014-01-01T01:00:00Z',
#   'tz_time': '2014-01-01T01:00:00.000Z',
#   'geo_id': 8741,
#   'geo_name': 'Península'},
#  {'value': 121152.0,
#   'datetime': '2014-01-01T03:00:00.000+01:00',
#   'datetime_utc': '2014-01-01T02:00:00Z',
#   'tz_time': '2014-01-01T02:00:00.000Z',
#   'geo_id': 8741,
#   'geo_name': 'Península'},
#  {'value': 115324.0,
#   'datetime': '2014-01-01T04:00:00.000+01:00',
#   'datetime_utc': '2014-01-01T03:00:00Z',
#   'tz_time': '2014-01-01T03:00:00.000Z',
# ...

# %%
value=[]
date_record=[]
hour=[]
for demanda_value in demanda_values:
    value.append(demanda_value['value'])
    date_record.append(demanda_value['datetime'][:10])
    hour.append(demanda_value['datetime'][11:13])

# %%
demanda_dataframe = pd.DataFrame({
    'date':date_record, 
    'hour':hour, 
    'value':value   
})

# %%
# value is on MW
demanda_dataframe
# Out:
#              date hour     value
# 0      2014-01-01   00  145810.0
# 1      2014-01-01   01  140192.0
# 2      2014-01-01   02  130035.0
# 3      2014-01-01   03  121152.0
# 4      2014-01-01   04  115324.0
# ...           ...  ...       ...
# 70123  2021-12-31   19  167097.0
# 70124  2021-12-31   20  165919.0
# 70125  2021-12-31   21  160479.0
# 70126  2021-12-31   22  143716.0
# 70127  2021-12-31   23   22755.0
#
# [70128 rows x 3 columns]

# %%
demanda_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70128 entries, 0 to 70127
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    70128 non-null  object
#  1   hour    70128 non-null  object
#  2   value   70128 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ MB

# %%
demanda_dataframe.to_csv(r'demanda_electrica_hora.csv', index=False)

# %%
demanda_dataframe = pd.read_csv('demanda_electrica_hora.csv')

# %%
demanda_dataframe['date'] = pd.to_datetime(demanda_dataframe.date) + pd.to_timedelta(pd.to_numeric(demanda_dataframe.hour), unit='h')
del demanda_dataframe['hour']
demanda_dataframe
# Out:
#                      date     value
# 0     2014-01-01 00:00:00  145810.0
# 1     2014-01-01 01:00:00  140192.0
# 2     2014-01-01 02:00:00  130035.0
# 3     2014-01-01 03:00:00  121152.0
# 4     2014-01-01 04:00:00  115324.0
# ...                   ...       ...
# 70123 2021-12-31 19:00:00  167097.0
# 70124 2021-12-31 20:00:00  165919.0
# 70125 2021-12-31 21:00:00  160479.0
# 70126 2021-12-31 22:00:00  143716.0
# 70127 2021-12-31 23:00:00   22755.0
#
# [70128 rows x 2 columns]

# %%
demanda_dataframe.set_index("date", inplace=True)
demanda_dataframe.head(2)
# Out:
#                         value
# date
# 2014-01-01 00:00:00  145810.0
# 2014-01-01 01:00:00  140192.0

# %%
demanda_dataframe = demanda_dataframe.resample('H').first()

# %%
demanda_dataframe.index.freq

# %%
# necesitamos establecer la frecuencia?
demanda_dataframe.index.freq='H'
demanda_dataframe.index
# Out:
# DatetimeIndex(['2014-01-01 00:00:00', '2014-01-01 01:00:00',
#                '2014-01-01 02:00:00', '2014-01-01 03:00:00',
#                '2014-01-01 04:00:00', '2014-01-01 05:00:00',
#                '2014-01-01 06:00:00', '2014-01-01 07:00:00',
#                '2014-01-01 08:00:00', '2014-01-01 09:00:00',
#                ...
#                '2021-12-31 14:00:00', '2021-12-31 15:00:00',
#                '2021-12-31 16:00:00', '2021-12-31 17:00:00',
#                '2021-12-31 18:00:00', '2021-12-31 19:00:00',
#                '2021-12-31 20:00:00', '2021-12-31 21:00:00',
#                '2021-12-31 22:00:00', '2021-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='date', length=70128, freq='H')

# %%
demanda_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 70128 entries, 2014-01-01 00:00:00 to 2021-12-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   70120 non-null  float64
# dtypes: float64(1)
# memory usage: 1.1 MB

# %%
demanda_dataframe.head()
# Out:
#                         value
# date
# 2014-01-01 00:00:00  145810.0
# 2014-01-01 01:00:00  140192.0
# 2014-01-01 02:00:00  130035.0
# 2014-01-01 03:00:00  121152.0
# 2014-01-01 04:00:00  115324.0

# %%
# primera visualización de la serie
demanda_dataframe.plot(figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
size = int(len(demanda_dataframe.dropna())*0.8)
size
# Out:
# 56096

# %%
train = demanda_dataframe.dropna().iloc[:size]
train.head()
# Out:
#                         value
# date
# 2014-01-01 00:00:00  145810.0
# 2014-01-01 01:00:00  140192.0
# 2014-01-01 02:00:00  130035.0
# 2014-01-01 03:00:00  121152.0
# 2014-01-01 04:00:00  115324.0

# %%
test = demanda_dataframe.dropna().iloc[size:]
test.tail()
# Out:
#                         value
# date
# 2021-12-31 19:00:00  167097.0
# 2021-12-31 20:00:00  165919.0
# 2021-12-31 21:00:00  160479.0
# 2021-12-31 22:00:00  143716.0
# 2021-12-31 23:00:00   22755.0

# %%
fitted_model_add = ExponentialSmoothing(train['value'], trend='add', seasonal='add', seasonal_periods=24).fit()
# Out:
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
test_predictions_hw_add=fitted_model_add.forecast(len(test))
test_predictions_hw_add
# Out:
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# 56096    165968.011973
# 56097    159921.681375
# 56098    157331.634193
# 56099    155657.400400
# 56100    155843.944211
#              ...
# 70115    216961.082256
# 70116    217147.626067
# 70117    219017.630324
# 70118    227779.259713
# 70119    231804.781924
# Length: 14024, dtype: float64

# %%
test['value_hw'] = np.asarray(test_predictions_hw_add)
test
# Out:
#                         value       value_hw
# date
# 2020-05-26 15:00:00  168026.0  165968.011973
# 2020-05-26 16:00:00  164402.0  159921.681375
# 2020-05-26 17:00:00  163332.0  157331.634193
# 2020-05-26 18:00:00  162510.0  155657.400400
# 2020-05-26 19:00:00  160103.0  155843.944211
# ...                       ...            ...
# 2021-12-31 19:00:00  167097.0  216961.082256
# 2021-12-31 20:00:00  165919.0  217147.626067
# 2021-12-31 21:00:00  160479.0  219017.630324
# 2021-12-31 22:00:00  143716.0  227779.259713
# 2021-12-31 23:00:00   22755.0  231804.781924
#
# [14024 rows x 2 columns]

# %%
train['value'].plot(legend=True,label='Train', figsize=(14,8))
test['value'].plot(legend=True,label='Test', figsize=(14,8))
test['value_hw'].plot(legend=True,label='HW', figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## ANÁLISIS MENSUAL

# %%
# ANÁLISIS MENSUAL
## analizar a nivel mensual cómo es la curva
### comprobar el error con el modelo HW

## y luego bajar a nivel diario
### Luego iría a nivel diario. Y ahí me centraría en un par de años para ver algún patrón

# %% [markdown]
# ### 1.- Extracción de los datos:

# %%
# mensual llamando a la api
start_date='01-01-2014T00:00:00 00:00'
end_date='31-12-2021T23:00:00 00:00'
date_type='datos'

url_resumen = 'https://api.esios.ree.es/indicators/1293/?start_date='+start_date+'&end_date='+end_date+'&time_trunc=month'
demanda_historico_mensual = requests.get(
    url_resumen, 
    headers = {
        'Accept': 'application/json; application/vnd.esios-api-v1+json',
        'Host' : 'api.esios.ree.es',
        'Content-Type':'application/json',
        'Authorization':'Token token="%s"' % (token),
        'Cookie': ''
    }
)

demanda_historico_mensual.json()
# Out:
# {'indicator': {'name': 'Demanda real',
#   'short_name': 'Demanda real',
#   'id': 1293,
#   'composited': False,
#   'step_type': 'linear',
#   'disaggregated': False,
#   'magnitud': [{'name': 'Potencia', 'id': 20}],
#   'tiempo': [{'name': 'Diez minutos', 'id': 225}],
#   'geos': [{'geo_id': 8741, 'geo_name': 'Península'}],
#   'values_updated_at': '2021-12-31T23:09:00.000+01:00',
#   'values': [{'value': 132056990.0,
#     'datetime': '2014-01-01T00:00:00.000+01:00',
#     'datetime_utc': '2013-12-31T23:00:00Z',
#     'tz_time': '2013-12-31T23:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 121688438.0,
#     'datetime': '2014-02-01T00:00:00.000+01:00',
#     'datetime_utc': '2014-01-31T23:00:00Z',
#     'tz_time': '2014-01-31T23:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 124724746.0,
#     'datetime': '2014-03-01T00:00:00.000+01:00',
#     'datetime_utc': '2014-02-28T23:00:00Z',
# ...

# %%
value=[]
date_record=[]
# hour=[]
for demanda_value in demanda_historico_mensual.json()['indicator']['values']:
    value.append(demanda_value['value'])
    date_record.append(demanda_value['datetime'][:10])

# %%
demanda_dataframe_month = pd.DataFrame({
    'date':date_record, 
    'value':value   
})

# %%
demanda_dataframe_month.head()
# Out:
#          date        value
# 0  2014-01-01  132056990.0
# 1  2014-02-01  121688438.0
# 2  2014-03-01  124724746.0
# 3  2014-04-01  112057243.0
# 4  2014-05-01  116035410.0

# %%
demanda_dataframe_month.to_csv(r'demanda_electrica_month.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31513/254586573.py in <module>
# ----> 1 demanda_dataframe_month.to_csv(r'demanda_electrica_month.csv', index=False)
#
# NameError: name 'demanda_dataframe_month' is not defined

# %%
demanda_dataframe_month = pd.read_csv('demanda_electrica_month.csv')

# %%
demanda_dataframe_month['date'] = pd.to_datetime(demanda_dataframe_month.date)
demanda_dataframe_month
# Out:
#          date        value
# 0  2014-01-01  132056990.0
# 1  2014-02-01  121688438.0
# 2  2014-03-01  124724746.0
# 3  2014-04-01  112057243.0
# 4  2014-05-01  116035410.0
# ..        ...          ...
# 91 2021-08-01  125111628.0
# 92 2021-09-01  118590191.0
# 93 2021-10-01  114687519.0
# 94 2021-11-01  122396779.0
# 95 2021-12-01  125184062.0
#
# [96 rows x 2 columns]

# %%
demanda_dataframe_month.set_index("date", inplace=True)
demanda_dataframe_month.head(2)
# Out:
#                   value
# date
# 2014-01-01  132056990.0
# 2014-02-01  121688438.0

# %%
demanda_dataframe_month = demanda_dataframe_month.resample('MS').first()

demanda_dataframe_month.index.freq

# %%
demanda_dataframe_month.index.freq='MS'
demanda_dataframe_month.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#                '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#                '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#                '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
# ...

# %%
# primera visualización de la serie
demanda_dataframe_month.plot(figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### 2.-Análisis de la Serie Temporal

# %%
# ¿es la serie estacionaria?

# %%
def adfuller_test(data):
    from statsmodels.tsa.stattools import adfuller
    
    result = adfuller(data)
    labels =['ADF Tesr Statistic','p-value','Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+": "+str(value))
    if result[1] <= 0.05:
        print("Conclusion: strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("Conclusion: weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(demanda_dataframe_month)
# Out:
# ADF Tesr Statistic: -1.34347257117945
# p-value: 0.6090564874005809
# Lags Used: 12
# Number of Observations Used: 83
# Conclusion: weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
# NOTA: no es estacionaria, necesitamos que lo sea

# %%
# vamos a ver cómo se distribuyen los datos de demanda de energía:

# %%
demanda_dataframe_month.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# NOTA: podemos observar una distribución casi normal en los datos de demanda energética

## (pendiente): comprobación estadística de que es normal/no-normal.

# %%
# In order to perform a time series analysis, we may need to separate seasonality and trend from our series. 
# The resultant series will become stationary through this process.

# So let us separate Trend and Seasonality from the time series.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(demanda_dataframe_month, model='multiplicative')
result.plot()
plt.show()

# %%
# NOTA: 
# tendencia: 
## podemos ver que la tendencia llega a lo más alto en el 2018 (alza económica?) para luego decaer a mínimos en 2020
## en 2020 ocurre la pandemia, lo cual explica el nivel bajo de demanda eléctrica, 
## pero ya desde 2018 se ve la tendencia a la baja

# tiene un marcado componente estacional: 
## se llega al máximo de demanda a principios de año, 
## cae a mínimo en los meses de primavera (menor consumo de energía en las casas) 
## para luego volver a subir a niveles casi máximos
## decae en los meses de otoño y vuelve a subir

# %%
# NOTA: To get a stationary series, we need to eliminate the trend and seasonality from the series.

# %% [markdown]
# ### 3.-Modelado Básico con HW

# %%
size = int(len(demanda_dataframe_month.dropna())*0.8)
size
# Out:
# 76

# %%
train = demanda_dataframe_month.dropna().iloc[:size]
train.head()
# Out:
#                   value
# date
# 2014-01-01  132056990.0
# 2014-02-01  121688438.0
# 2014-03-01  124724746.0
# 2014-04-01  112057243.0
# 2014-05-01  116035410.0

# %%
test = demanda_dataframe_month.dropna().iloc[size:]
test.tail()
# Out:
#                   value
# date
# 2021-08-01  125111628.0
# 2021-09-01  118590191.0
# 2021-10-01  114687519.0
# 2021-11-01  122396779.0
# 2021-12-01  125184062.0

# %%
fitted_model_add = ExponentialSmoothing(train['value'], trend='add', seasonal='add', seasonal_periods=12).fit()
# Out:
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
test_predictions_hw_add=fitted_model_add.forecast(len(test))
test_predictions_hw_add
# Out:
# /home/berni/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)
# 2020-05-01    1.146358e+08
# 2020-06-01    1.167931e+08
# 2020-07-01    1.281554e+08
# 2020-08-01    1.216296e+08
# 2020-09-01    1.154982e+08
# 2020-10-01    1.136873e+08
# 2020-11-01    1.158331e+08
# 2020-12-01    1.198827e+08
# 2021-01-01    1.277717e+08
# 2021-02-01    1.138372e+08
# 2021-03-01    1.163433e+08
# 2021-04-01    1.062363e+08
# 2021-05-01    1.087775e+08
# 2021-06-01    1.109347e+08
# 2021-07-01    1.222971e+08
# 2021-08-01    1.157713e+08
# 2021-09-01    1.096399e+08
# 2021-10-01    1.078290e+08
# 2021-11-01    1.099748e+08
# 2021-12-01    1.140244e+08
# Freq: MS, dtype: float64

# %%
test['value_hw'] = np.asarray(test_predictions_hw_add)
test
# Out:
#                   value      value_hw
# date
# 2020-05-01  104873485.0  1.146358e+08
# 2020-06-01  110791725.0  1.167931e+08
# 2020-07-01  132338897.0  1.281554e+08
# 2020-08-01  125083657.0  1.216296e+08
# 2020-09-01  116977670.0  1.154982e+08
# 2020-10-01  118106162.0  1.136873e+08
# 2020-11-01  118559520.0  1.158331e+08
# 2020-12-01  127818422.0  1.198827e+08
# 2021-01-01  137622023.0  1.277717e+08
# 2021-02-01  115952775.0  1.138372e+08
# 2021-03-01  125109453.0  1.163433e+08
# 2021-04-01  113705704.0  1.062363e+08
# 2021-05-01  115825967.0  1.087775e+08
# 2021-06-01  118353376.0  1.109347e+08
# 2021-07-01  130518722.0  1.222971e+08
# 2021-08-01  125111628.0  1.157713e+08
# 2021-09-01  118590191.0  1.096399e+08
# 2021-10-01  114687519.0  1.078290e+08
# 2021-11-01  122396779.0  1.099748e+08
# 2021-12-01  125184062.0  1.140244e+08

# %%
train['value'].plot(legend=True,label='Train', figsize=(14,8))
test['value'].plot(legend=True,label='Test', figsize=(14,8))
test['value_hw'].plot(legend=True,label='HW', figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#NOTA:  se ve la caída por el COVID-19

# %%
# vamos a ver el RMSE y otras métricas para hacernos una idea

# %% [markdown]
# ### Pruebas con la distribución por día (mes de enero)

# %%
energy_demand_hourly = pd.read_csv('demanda_electrica_hora_weekday.csv')
energy_demand_hourly
# Out:
#              date  hour     value  weekday  working_day
# 0      2014-01-01     0  145810.0        2            0
# 1      2014-01-01     1  140192.0        2            0
# 2      2014-01-01     2  130035.0        2            0
# 3      2014-01-01     3  121152.0        2            0
# 4      2014-01-01     4  115324.0        2            0
# ...           ...   ...       ...      ...          ...
# 70123  2021-12-31    19  167097.0        4            1
# 70124  2021-12-31    20  165919.0        4            1
# 70125  2021-12-31    21  160479.0        4            1
# 70126  2021-12-31    22  143716.0        4            1
# 70127  2021-12-31    23   22755.0        4            1
#
# [70128 rows x 5 columns]

# %%
# new column date as date+hour:
energy_demand_hourly['date'] = pd.to_datetime(energy_demand_hourly.date) + pd.to_timedelta(energy_demand_hourly.hour, unit='h')
del energy_demand_hourly['hour']

# convert date as index:
energy_demand_hourly.set_index("date", inplace=True)

# set freq as hourly:
energy_demand_hourly = energy_demand_hourly.resample('H').first()
energy_demand_hourly.index.freq

# show first two rows:
energy_demand_hourly.head(2)
# Out:
#                         value  weekday  working_day
# date
# 2014-01-01 00:00:00  145810.0      2.0          0.0
# 2014-01-01 01:00:00  140192.0      2.0          0.0

# %%
energy_demand_hourly.index
# Out:
# DatetimeIndex(['2014-01-01 00:00:00', '2014-01-01 01:00:00',
#                '2014-01-01 02:00:00', '2014-01-01 03:00:00',
#                '2014-01-01 04:00:00', '2014-01-01 05:00:00',
#                '2014-01-01 06:00:00', '2014-01-01 07:00:00',
#                '2014-01-01 08:00:00', '2014-01-01 09:00:00',
#                ...
#                '2021-12-31 14:00:00', '2021-12-31 15:00:00',
#                '2021-12-31 16:00:00', '2021-12-31 17:00:00',
#                '2021-12-31 18:00:00', '2021-12-31 19:00:00',
#                '2021-12-31 20:00:00', '2021-12-31 21:00:00',
#                '2021-12-31 22:00:00', '2021-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='date', length=70128, freq='H')

# %%
# pruebas: calcular el valor medio de cada hora entre todos los valores de la misma hora en diferentes años

# %%
day_hour_means_values = energy_demand_hourly.groupby(lambda x: (x.day, x.hour)).mean()

day_hour_means_values
# Out:
#                   value   weekday  working_day
# (1, 0)    154049.052083  2.989583     0.739583
# (1, 1)    144672.041667  2.989583     0.739583
# (1, 2)    137456.500000  2.989583     0.739583
# (1, 3)    133529.843750  2.989583     0.739583
# (1, 4)    131577.239583  2.989583     0.739583
# ...                 ...       ...          ...
# (31, 19)  181134.392857  3.142857     1.000000
# (31, 20)  182160.071429  3.142857     1.000000
# (31, 21)  183985.035714  3.142857     1.000000
# (31, 22)  174832.589286  3.142857     1.000000
# (31, 23)  160453.571429  3.142857     1.000000
#
# [744 rows x 3 columns]

# %%
# pruebas: calcular el valor medio de cada hora entre todos los valores de la misma hora en diferentes años

# %%
# extraemos los valores de cada año por mes (de enero en este caso)
# 2014:
energy_demand_hourly_january_2014 = energy_demand_hourly.loc['2014-01']
energy_demand_hourly_january_2014.index = pd.to_datetime(
    energy_demand_hourly_january_2014.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2015:
energy_demand_hourly_january_2015 = energy_demand_hourly.loc['2015-01']
energy_demand_hourly_january_2015.index = pd.to_datetime(
    energy_demand_hourly_january_2015.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2016:
energy_demand_hourly_january_2016 = energy_demand_hourly.loc['2016-01']
energy_demand_hourly_january_2016.index = pd.to_datetime(
    energy_demand_hourly_january_2016.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2017:
energy_demand_hourly_january_2017 = energy_demand_hourly.loc['2017-01']
energy_demand_hourly_january_2017.index = pd.to_datetime(
    energy_demand_hourly_january_2017.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2018:
energy_demand_hourly_january_2018 = energy_demand_hourly.loc['2018-01']
energy_demand_hourly_january_2018.index = pd.to_datetime(
    energy_demand_hourly_january_2018.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2019:
energy_demand_hourly_january_2019 = energy_demand_hourly.loc['2019-01']
energy_demand_hourly_january_2019.index = pd.to_datetime(
    energy_demand_hourly_january_2019.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2020:
energy_demand_hourly_january_2020 = energy_demand_hourly.loc['2020-01']
energy_demand_hourly_january_2020.index = pd.to_datetime(
    energy_demand_hourly_january_2020.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')
# 2021:
energy_demand_hourly_january_2021 = energy_demand_hourly.loc['2021-01']
energy_demand_hourly_january_2021.index = pd.to_datetime(
    energy_demand_hourly_january_2021.index, 
    format = '%Y-%m-%d').strftime('%m-%d %H')

# %%
energy_demand_january_resume = pd.DataFrame()

energy_demand_january_resume['value_2014'] = energy_demand_hourly_january_2014['value']
energy_demand_january_resume['value_2015'] = energy_demand_hourly_january_2015['value']
energy_demand_january_resume['value_2016'] = energy_demand_hourly_january_2016['value']
energy_demand_january_resume['value_2017'] = energy_demand_hourly_january_2017['value']
energy_demand_january_resume['value_2018'] = energy_demand_hourly_january_2018['value']
energy_demand_january_resume['value_2019'] = energy_demand_hourly_january_2019['value']
energy_demand_january_resume['value_2020'] = energy_demand_hourly_january_2020['value']
energy_demand_january_resume['value_2021'] = energy_demand_hourly_january_2021['value']

energy_demand_january_resume['mean_value'] = energy_demand_january_resume.mean(numeric_only=True, axis=1)

energy_demand_january_resume
# Out:
#           value_2014  value_2015  value_2016  value_2017  value_2018  \
# date
# 01-01 00    145810.0    152610.0    134922.0    146834.0    136969.0
# 01-01 01    140192.0    147069.0    130471.0    141117.0    132750.0
# 01-01 02    130035.0    137197.0    122900.0    132157.0    124299.0
# 01-01 03    121152.0    128357.0    115478.0    124264.0    117685.0
# 01-01 04    115324.0    121918.0    110149.0    118132.0    113498.0
# ...              ...         ...         ...         ...         ...
# 01-31 19    216564.0    195785.0    177228.0    217454.0    218623.0
# 01-31 20    215911.0    199509.0    184879.0    219890.0    222694.0
# 01-31 21    213669.0    198256.0    185865.0    216986.0    219384.0
# 01-31 22    201596.0    189672.0    181128.0    200915.0    204078.0
# 01-31 23    186430.0    178240.0    167690.0    181528.0    183858.0
#
#           value_2019  value_2020  value_2021  mean_value
# date
# 01-01 00    140754.0    138006.0    148337.0  143030.250
# ...

# %%
plt.title("January Hourly Demand 2014-2021", size = 20)
energy_demand_hourly_january_2014['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2015['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2016['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2017['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2018['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2019['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2020['value'].plot(color='grey', figsize=(12,6))
energy_demand_hourly_january_2021['value'].plot(color='grey', figsize=(12,6))

# day_hour_means_values
energy_demand_january_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'January Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# automatizamos para el resto de meses

def prepare_month_data(month):
    years = ['2014-', '2015-', '2016-', '2017-', '2018-', '2019-', '2020-', '2021-']
    month_year = [s + month for s in years]
    # load data:
    energy_demand_hourly = pd.read_csv('demanda_electrica_hora_weekday.csv')
    # new column date as date+hour:
    energy_demand_hourly['date'] = pd.to_datetime(energy_demand_hourly.date) + pd.to_timedelta(energy_demand_hourly.hour, unit='h')
    del energy_demand_hourly['hour']
    # convert date as index:
    energy_demand_hourly.set_index("date", inplace=True)
    # set freq as hourly:
    energy_demand_hourly = energy_demand_hourly.resample('H').first()
    energy_demand_hourly.index.freq
    # create a dataframe resume:
    energy_demand_month_resume = pd.DataFrame()
    for month in month_year:
        energy_demand_hourly_month_year = energy_demand_hourly.loc[month]
        energy_demand_hourly_month_year.index = pd.to_datetime(
            energy_demand_hourly_month_year.index, 
            format = '%Y-%m-%d').strftime('%m-%d %H')
        
        energy_demand_month_resume[month] = energy_demand_hourly_month_year['value']
        
    energy_demand_month_resume['mean_value'] = energy_demand_month_resume.mean(numeric_only=True, axis=1)
    
    return energy_demand_month_resume

# %%
# prepare data
january_resume = prepare_month_data('01')
# print data
plt.title("January Hourly Demand 2014-2021", size = 20)
january_resume['2014-01'].plot(color='grey', figsize=(12,6))
january_resume['2015-01'].plot(color='grey', figsize=(12,6))
january_resume['2016-01'].plot(color='grey', figsize=(12,6))
january_resume['2017-01'].plot(color='grey', figsize=(12,6))
january_resume['2018-01'].plot(color='grey', figsize=(12,6))
january_resume['2019-01'].plot(color='grey', figsize=(12,6))
january_resume['2020-01'].plot(color='grey', figsize=(12,6))
january_resume['2021-01'].plot(color='grey', figsize=(12,6))
january_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'January Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
february_resume = prepare_month_data('02')
# print data
plt.title("February Hourly Demand 2014-2021", size = 20)
february_resume['2014-02'].plot(color='grey', figsize=(12,6))
february_resume['2015-02'].plot(color='grey', figsize=(12,6))
february_resume['2016-02'].plot(color='grey', figsize=(12,6))
february_resume['2017-02'].plot(color='grey', figsize=(12,6))
february_resume['2018-02'].plot(color='grey', figsize=(12,6))
february_resume['2019-02'].plot(color='grey', figsize=(12,6))
february_resume['2020-02'].plot(color='grey', figsize=(12,6))
february_resume['2021-02'].plot(color='grey', figsize=(12,6))
february_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'February Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
march_resume = prepare_month_data('03')
# print data
plt.title("March Hourly Demand 2014-2021", size = 20)
march_resume['2014-03'].plot(color='grey', figsize=(12,6))
march_resume['2015-03'].plot(color='grey', figsize=(12,6))
march_resume['2016-03'].plot(color='grey', figsize=(12,6))
march_resume['2017-03'].plot(color='grey', figsize=(12,6))
march_resume['2018-03'].plot(color='grey', figsize=(12,6))
march_resume['2019-03'].plot(color='grey', figsize=(12,6))
march_resume['2020-03'].plot(color='grey', figsize=(12,6))
march_resume['2021-03'].plot(color='grey', figsize=(12,6))
march_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'March Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
april_resume = prepare_month_data('04')
# print data
plt.title("April Hourly Demand 2014-2021", size = 20)
april_resume['2014-04'].plot(color='grey', figsize=(12,6))
april_resume['2015-04'].plot(color='grey', figsize=(12,6))
april_resume['2016-04'].plot(color='grey', figsize=(12,6))
april_resume['2017-04'].plot(color='grey', figsize=(12,6))
april_resume['2018-04'].plot(color='grey', figsize=(12,6))
april_resume['2019-04'].plot(color='grey', figsize=(12,6))
april_resume['2020-04'].plot(color='grey', figsize=(12,6))
april_resume['2021-04'].plot(color='grey', figsize=(12,6))
april_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'April Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
may_resume = prepare_month_data('05')
# print data
plt.title("May Hourly Demand 2014-2021", size = 20)
may_resume['2014-05'].plot(color='grey', figsize=(12,6))
may_resume['2015-05'].plot(color='grey', figsize=(12,6))
may_resume['2016-05'].plot(color='grey', figsize=(12,6))
may_resume['2017-05'].plot(color='grey', figsize=(12,6))
may_resume['2018-05'].plot(color='grey', figsize=(12,6))
may_resume['2019-05'].plot(color='grey', figsize=(12,6))
may_resume['2020-05'].plot(color='grey', figsize=(12,6))
may_resume['2021-05'].plot(color='grey', figsize=(12,6))
may_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'May Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
june_resume = prepare_month_data('06')
# print data
plt.title("June Hourly Demand 2014-2021", size = 20)
june_resume['2014-06'].plot(color='grey', figsize=(12,6))
june_resume['2015-06'].plot(color='grey', figsize=(12,6))
june_resume['2016-06'].plot(color='grey', figsize=(12,6))
june_resume['2017-06'].plot(color='grey', figsize=(12,6))
june_resume['2018-06'].plot(color='grey', figsize=(12,6))
june_resume['2019-06'].plot(color='grey', figsize=(12,6))
june_resume['2020-06'].plot(color='grey', figsize=(12,6))
june_resume['2021-06'].plot(color='grey', figsize=(12,6))
june_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'June Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
july_resume = prepare_month_data('07')
# print data
plt.title("July Hourly Demand 2014-2021", size = 20)
july_resume['2014-07'].plot(color='grey', figsize=(12,6))
july_resume['2015-07'].plot(color='grey', figsize=(12,6))
july_resume['2016-07'].plot(color='grey', figsize=(12,6))
july_resume['2017-07'].plot(color='grey', figsize=(12,6))
july_resume['2018-07'].plot(color='grey', figsize=(12,6))
july_resume['2019-07'].plot(color='grey', figsize=(12,6))
july_resume['2020-07'].plot(color='grey', figsize=(12,6))
july_resume['2021-07'].plot(color='grey', figsize=(12,6))
july_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'July Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
august_resume = prepare_month_data('08')
# print data
plt.title("August Hourly Demand 2014-2021", size = 20)
august_resume['2014-08'].plot(color='grey', figsize=(12,6))
august_resume['2015-08'].plot(color='grey', figsize=(12,6))
august_resume['2016-08'].plot(color='grey', figsize=(12,6))
august_resume['2017-08'].plot(color='grey', figsize=(12,6))
august_resume['2018-08'].plot(color='grey', figsize=(12,6))
august_resume['2019-08'].plot(color='grey', figsize=(12,6))
august_resume['2020-08'].plot(color='grey', figsize=(12,6))
august_resume['2021-08'].plot(color='grey', figsize=(12,6))
august_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'August Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
september_resume = prepare_month_data('09')
# print data
plt.title("September Hourly Demand 2014-2021", size = 20)
september_resume['2014-09'].plot(color='grey', figsize=(12,6))
september_resume['2015-09'].plot(color='grey', figsize=(12,6))
september_resume['2016-09'].plot(color='grey', figsize=(12,6))
september_resume['2017-09'].plot(color='grey', figsize=(12,6))
september_resume['2018-09'].plot(color='grey', figsize=(12,6))
september_resume['2019-09'].plot(color='grey', figsize=(12,6))
september_resume['2020-09'].plot(color='grey', figsize=(12,6))
september_resume['2021-09'].plot(color='grey', figsize=(12,6))
september_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'September Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
october_resume = prepare_month_data('10')
# print data
plt.title("October Hourly Demand 2014-2021", size = 20)
october_resume['2014-10'].plot(color='grey', figsize=(12,6))
october_resume['2015-10'].plot(color='grey', figsize=(12,6))
october_resume['2016-10'].plot(color='grey', figsize=(12,6))
october_resume['2017-10'].plot(color='grey', figsize=(12,6))
october_resume['2018-10'].plot(color='grey', figsize=(12,6))
october_resume['2019-10'].plot(color='grey', figsize=(12,6))
october_resume['2020-10'].plot(color='grey', figsize=(12,6))
october_resume['2021-10'].plot(color='grey', figsize=(12,6))
october_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'October Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
november_resume = prepare_month_data('11')
# print data
plt.title("November Hourly Demand 2014-2021", size = 20)
november_resume['2014-11'].plot(color='grey', figsize=(12,6))
november_resume['2015-11'].plot(color='grey', figsize=(12,6))
november_resume['2016-11'].plot(color='grey', figsize=(12,6))
november_resume['2017-11'].plot(color='grey', figsize=(12,6))
november_resume['2018-11'].plot(color='grey', figsize=(12,6))
november_resume['2019-11'].plot(color='grey', figsize=(12,6))
november_resume['2020-11'].plot(color='grey', figsize=(12,6))
november_resume['2021-11'].plot(color='grey', figsize=(12,6))
november_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'November Hourly Demand 2014-2021'}, xlabel='date'>

# %%
# prepare data
december_resume = prepare_month_data('12')
# print data
plt.title("December Hourly Demand 2014-2021", size = 20)
december_resume['2014-12'].plot(color='grey', figsize=(12,6))
december_resume['2015-12'].plot(color='grey', figsize=(12,6))
december_resume['2016-12'].plot(color='grey', figsize=(12,6))
december_resume['2017-12'].plot(color='grey', figsize=(12,6))
december_resume['2018-12'].plot(color='grey', figsize=(12,6))
december_resume['2019-12'].plot(color='grey', figsize=(12,6))
december_resume['2020-12'].plot(color='grey', figsize=(12,6))
december_resume['2021-12'].plot(color='grey', figsize=(12,6))
december_resume['mean_value'].plot(color='blue', figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'December Hourly Demand 2014-2021'}, xlabel='date'>
